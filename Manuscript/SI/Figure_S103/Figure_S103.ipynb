# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../main_text/Figure_6/result_analysis_time.csv')

print(df)
# Out:
#           name  volumetric_time  SKID_time
# 0  Zeolite 13X             1283        105
# 1      ROS-040              540         25
# 2        ZIF-7              345         25

# %% [markdown]
# ### measurement time: equilibrium vs kinetics

# %%
text_size = 18
fig, ax = plt.subplots(1, 1, figsize=(15, 7.5))
ax.bar(df.name, df.volumetric_time, label='equilibrium')
ax.bar(df.name, df.SKID_time, label='kinetics')
ax.set_xlabel('material', fontsize=text_size)
ax.set_ylabel('measurement time, min', fontsize=text_size)
ax.tick_params(axis='x', rotation=90, labelsize=text_size)
ax.tick_params(axis='y', labelsize=text_size)
#ax.legend()
fig.tight_layout()
plt.savefig('Figure_S103.png', dpi=600)
plt.show()
